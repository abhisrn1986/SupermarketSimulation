# %%
import pandas as pd
penguins=pd.read_csv("penguins_simple.csv",sep=";")
penguins
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    Adelie                39.1               18.7                181.0
# 1    Adelie                39.5               17.4                186.0
# 2    Adelie                40.3               18.0                195.0
# 3    Adelie                36.7               19.3                193.0
# 4    Adelie                39.3               20.6                190.0
# ..      ...                 ...                ...                  ...
# 328  Gentoo                47.2               13.7                214.0
# 329  Gentoo                46.8               14.3                215.0
# 330  Gentoo                50.4               15.7                222.0
# 331  Gentoo                45.2               14.8                212.0
# 332  Gentoo                49.9               16.1                213.0
#
#      Body Mass (g)     Sex
# 0           3750.0    MALE
# 1           3800.0  FEMALE
# ...

# %%
penguins.describe()
# Out:
#        Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# count          333.000000         333.000000           333.000000
# mean            43.992793          17.164865           200.966967
# std              5.468668           1.969235            14.015765
# min             32.100000          13.100000           172.000000
# 25%             39.500000          15.600000           190.000000
# 50%             44.500000          17.300000           197.000000
# 75%             48.600000          18.700000           213.000000
# max             59.600000          21.500000           231.000000
#
#        Body Mass (g)
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000

# %% [markdown]
# **Draw a one plot**

# %%
penguins["Body Mass (g)"].plot()
# Out:
# <AxesSubplot:>

# %%
penguins["Body Mass (g)"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
penguins["Body Mass (g)"].loc[penguins["Sex"]=="FEMALE"].plot(alpha=0.8,kind="hist",color="salmon")
penguins["Body Mass (g)"].loc[penguins["Sex"]=="MALE"].plot(alpha=0.8,kind="hist",color="dodgerblue")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# **MATPLOTLIB**

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# **Build the next plot up gradually**

# %%
plt.figure(figsize=(10,5))
plt.scatter(penguins["Culmen Depth (mm)"],penguins["Flipper Length (mm)"],s=100,color="green",marker="o")
plt.xlabel("Culmen Depth in mm",fontsize=15)
plt.xticks()
plt.ylabel("Culmen Length in mm",fontsize=15)
plt.title("Culmen Length and Depth",fontsize=20)
plt.show()

# %% [markdown]
# **Multiple plots in one**

# %%
plt.figure(figsize=(10,5))
plt.style.use("ggplot")
plt.plot(penguins["Culmen Length (mm)"],label="Culmen Length in mm")
plt.plot(penguins["Culmen Depth (mm)"],label="Culmen Depth in mm")
plt.legend()

# %% [markdown]
# **Seaborn**

# %%
import seaborn as sns  #!pip install seaborn

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=penguins,x="Culmen Length (mm)",y="Culmen Depth (mm)",hue="Species")
plt.title("Culmen Length and Depth")
plt.show()

# %%
sns.displot(penguins["Body Mass (g)"])

# %%
sns.pairplot(data=penguins,hue="Species")

# %%
fig, (ax1,ax2)=plt.subplots(nrows=2,ncols=1)
ax1.plot(penguins["Culmen Length (mm)"]) #species first columnn
ax2.plot(penguins["Culmen Depth (mm)"])  #species second column

# %% [markdown]
# **Descriptive Statistic**

# %% [markdown]
# #A set of methods and measures to describe a dataset. summarization of data and provides language to talk about it.
#
# 1-Variable Types:
# a)Nominal-Categorical_ names, albels,categories thar are not conected , no oreder.
# can be analysed (mode)
# could be boolsan or multi-label
# b)Ordianal:
# variable with an order or relative rank. peguin health status: poor, medium. good. excellent
# c)Metric:
# Quantitive values
# Natural ordering, ddifference is measurable.
# Discrete.

# %% [markdown]
# **Measures of central tendency**

# %% [markdown]
# 1)Mean
#     a)Aritmetuc mean
#     b)Weighted arithmetic mean(It is used generally in Survey)
#     c)Geometric mean( Finance, also often used with rates of return)
#     d)Harmanic mean (Inver observation, then tke the average)
#     e)Mean:
#     f)Mode: Most frequent
# 2)Measures of dispersion/spread
#     a)Range
#     b)Interquartile Range(IQR)
#     c)Variance

# %% [markdown]
# **Corelation**

# %% [markdown]
# # Positive and negative
# +1,0,-1 ***

# %% [markdown]
# #### Exercises with seaborn and matplotlib:
# - Draw a histogram that shows how many penguins of each species are in the data
# - create a plot of your choosing that only shows the data of female Gentoos.
# - Create a scatterplot of the culmen length and depth where the size of the markers represent the Body mass of the penguin
# - Find at least one more way (besides a scatterplot) to visualize the relationship between culmen lenght and depth (or another bivariate distribution)

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
penguins["Species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# **1)Draw a histogram that shows how many penguins of each species are in the data**

# %%
sns.histplot(penguins['Species'])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Count'>

# %% [markdown]
# **2)Create a plot of your choosing that only shows the data of female Gentoos.**

# %%
sns.pairplot(data=penguins[(penguins['Sex'] == 'FEMALE') & (penguins['Species'] == 'Gentoo')],hue='Species')

# %% [markdown]
# 3)Create a scatterplot of the culmen length and depth where the size of the markers represent the Body mass of the penguin

# %%
sns.scatterplot(data=penguins, x='Culmen Length (mm)', y='Culmen Depth (mm)', size='Body Mass (g)',sizes=(20,200))
# Out:
# <AxesSubplot:xlabel='Culmen Length (mm)', ylabel='Culmen Depth (mm)'>

# %% [markdown]
# **- Find at least one more way (besides a scatterplot) to visualize the relationship between culmen lenght and depth (or another bivariate distribution)**
