# %% [markdown]
# # Data Wrangling with Penguins

# %% [markdown]
# #### 🎯 Merge and join multiple tables together

# %% [markdown]
# ### Load all our data

# %% [markdown]
# **Each penguin species is in a different file.
# **Sex data isn't included

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
adelie_df=pd.read_csv("../Day5/data/penguins_adelie.csv")
adelie_df
# Out:
#     studyName  Sample Number Species Sample ID  Region     Island  \
# 0     PAL0708              1  Adelie       A_1  Anvers  Torgersen
# 1     PAL0708              2  Adelie       A_2  Anvers  Torgersen
# 2     PAL0708              3  Adelie       A_3  Anvers  Torgersen
# 3     PAL0708              4  Adelie       A_4  Anvers  Torgersen
# 4     PAL0708              5  Adelie       A_5  Anvers  Torgersen
# ..        ...            ...     ...       ...     ...        ...
# 147   PAL0910            148  Adelie     A_148  Anvers      Dream
# 148   PAL0910            149  Adelie     A_149  Anvers      Dream
# 149   PAL0910            150  Adelie     A_150  Anvers      Dream
# 150   PAL0910            151  Adelie     A_151  Anvers      Dream
# 151   PAL0910            152  Adelie     A_152  Anvers      Dream
#
#     Individual ID  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0            N1A1                39.1               18.7                181.0
# ...

# %%
chinstrap_df=pd.read_csv("../Day5/data/penguins_chinstrap.csv")
chinstrap_df
# Out:
#    studyName  Sample Number    Species Sample ID  Region Island Individual ID  \
# 0    PAL0708              1  Chinstrap       C_1  Anvers  Dream         N61A1
# 1    PAL0708              2  Chinstrap       C_2  Anvers  Dream         N61A2
# 2    PAL0708              3  Chinstrap       C_3  Anvers  Dream         N62A1
# 3    PAL0708              4  Chinstrap       C_4  Anvers  Dream         N62A2
# 4    PAL0708              5  Chinstrap       C_5  Anvers  Dream         N64A1
# ..       ...            ...        ...       ...     ...    ...           ...
# 63   PAL0910             64  Chinstrap      C_64  Anvers  Dream         N98A2
# 64   PAL0910             65  Chinstrap      C_65  Anvers  Dream         N99A1
# 65   PAL0910             66  Chinstrap      C_66  Anvers  Dream         N99A2
# 66   PAL0910             67  Chinstrap      C_67  Anvers  Dream        N100A1
# 67   PAL0910             68  Chinstrap      C_68  Anvers  Dream        N100A2
#
# ...

# %%
gentoo_df=pd.read_csv("../Day5/data/penguins_gentoo.csv")
gentoo_df
# Out:
#     studyName  Sample Number Species Sample ID  Region  Island Individual ID  \
# 0     PAL0708              1  Gentoo       G_1  Anvers  Biscoe         N31A1
# 1     PAL0708              2  Gentoo       G_2  Anvers  Biscoe         N31A2
# 2     PAL0708              3  Gentoo       G_3  Anvers  Biscoe         N32A1
# 3     PAL0708              4  Gentoo       G_4  Anvers  Biscoe         N32A2
# 4     PAL0708              5  Gentoo       G_5  Anvers  Biscoe         N33A1
# ..        ...            ...     ...       ...     ...     ...           ...
# 119   PAL0910            120  Gentoo     G_120  Anvers  Biscoe         N38A2
# 120   PAL0910            121  Gentoo     G_121  Anvers  Biscoe         N39A1
# 121   PAL0910            122  Gentoo     G_122  Anvers  Biscoe         N39A2
# 122   PAL0910            123  Gentoo     G_123  Anvers  Biscoe         N43A1
# 123   PAL0910            124  Gentoo     G_124  Anvers  Biscoe         N43A2
#
# ...

# %%
penguins_sex_df=pd.read_csv("../Day5/data/sex_data_penguins.csv")
penguins_sex_df
# Out:
#         Sex  Sample Number Species
# 0      MALE              1  Adelie
# 1    FEMALE              2  Adelie
# 2    FEMALE              3  Adelie
# 3       NaN              4  Adelie
# 4      MALE              6  Adelie
# ..      ...            ...     ...
# 332     NaN            120  Gentoo
# 333  FEMALE            121  Gentoo
# 334    MALE            122  Gentoo
# 335  FEMALE            123  Gentoo
# 336    MALE            124  Gentoo
#
# [337 rows x 3 columns]

# %%
penguins_simple_df=pd.read_csv("../Day5/data/penguins_simple.csv",sep=";")
penguins_simple_df
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    Adelie                39.1               18.7                181.0
# 1    Adelie                39.5               17.4                186.0
# 2    Adelie                40.3               18.0                195.0
# 3    Adelie                36.7               19.3                193.0
# 4    Adelie                39.3               20.6                190.0
# ..      ...                 ...                ...                  ...
# 328  Gentoo                47.2               13.7                214.0
# 329  Gentoo                46.8               14.3                215.0
# 330  Gentoo                50.4               15.7                222.0
# 331  Gentoo                45.2               14.8                212.0
# 332  Gentoo                49.9               16.1                213.0
#
#      Body Mass (g)     Sex
# 0           3750.0    MALE
# 1           3800.0  FEMALE
# ...

# %% [markdown]
# *** str[] it is given that letter of your string column**

# %%
penguins_sex_df["Sample ID"]=penguins_sex_df["Species"].str[0]+"_" +penguins_sex_df["Sample Number"].astype(str)
penguins_sex_df
# Out:
#         Sex  Sample Number Species Sample ID
# 0      MALE              1  Adelie       A_1
# 1    FEMALE              2  Adelie       A_2
# 2    FEMALE              3  Adelie       A_3
# 3       NaN              4  Adelie       A_4
# 4      MALE              6  Adelie       A_6
# ..      ...            ...     ...       ...
# 332     NaN            120  Gentoo     G_120
# 333  FEMALE            121  Gentoo     G_121
# 334    MALE            122  Gentoo     G_122
# 335  FEMALE            123  Gentoo     G_123
# 336    MALE            124  Gentoo     G_124
#
# [337 rows x 4 columns]

# %%
penguins_sex_df.drop(["Sample Number","Species"],axis=1,inplace=True)

# %%
penguins_sex_df
# Out:
#         Sex Sample ID
# 0      MALE       A_1
# 1    FEMALE       A_2
# 2    FEMALE       A_3
# 3       NaN       A_4
# 4      MALE       A_6
# ..      ...       ...
# 332     NaN     G_120
# 333  FEMALE     G_121
# 334    MALE     G_122
# 335  FEMALE     G_123
# 336    MALE     G_124
#
# [337 rows x 2 columns]

# %% [markdown]
# ### Create one joint DataFrame

# %% [markdown]
# #### 1. Put different species in one DataFrame

# %% [markdown]
# **Anaother mehod**/n
# #penguins_df=adelie.df.append(chriistrap_df).append(gentoo_df)

# %%
df_unionx= pd.concat([adelie_df,chinstrap_df,gentoo_df])
print(df_unionx)
# Out:
#     studyName  Sample Number Species Sample ID  Region     Island  \
# 0     PAL0708              1  Adelie       A_1  Anvers  Torgersen
# 1     PAL0708              2  Adelie       A_2  Anvers  Torgersen
# 2     PAL0708              3  Adelie       A_3  Anvers  Torgersen
# 3     PAL0708              4  Adelie       A_4  Anvers  Torgersen
# 4     PAL0708              5  Adelie       A_5  Anvers  Torgersen
# ..        ...            ...     ...       ...     ...        ...
# 119   PAL0910            120  Gentoo     G_120  Anvers     Biscoe
# 120   PAL0910            121  Gentoo     G_121  Anvers     Biscoe
# 121   PAL0910            122  Gentoo     G_122  Anvers     Biscoe
# 122   PAL0910            123  Gentoo     G_123  Anvers     Biscoe
# 123   PAL0910            124  Gentoo     G_124  Anvers     Biscoe
#
#     Individual ID  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0            N1A1                39.1               18.7                181.0
# ...

# %% [markdown]
# #### 2. Combine the sex data with the rest

# %%
#inner merge /join:keeps only the records that exist in both 
pd.merge(penguins_simple_df,penguins_sex_df,how="inner")
# Out:
#       Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0      Adelie                39.1               18.7                181.0
# 1      Adelie                39.1               18.7                181.0
# 2      Adelie                39.1               18.7                181.0
# 3      Adelie                39.1               18.7                181.0
# 4      Adelie                39.1               18.7                181.0
# ...       ...                 ...                ...                  ...
# 54280  Gentoo                45.2               14.8                212.0
# 54281  Gentoo                45.2               14.8                212.0
# 54282  Gentoo                45.2               14.8                212.0
# 54283  Gentoo                45.2               14.8                212.0
# 54284  Gentoo                45.2               14.8                212.0
#
#        Body Mass (g)     Sex Sample ID
# 0             3750.0    MALE       A_1
# ...

# %%
#outer merge /join:keeps all records that exist in both 
pd.merge(penguins_simple_df,penguins_sex_df,how="outer")
# Out:
#       Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0      Adelie                39.1               18.7                181.0
# 1      Adelie                39.1               18.7                181.0
# 2      Adelie                39.1               18.7                181.0
# 3      Adelie                39.1               18.7                181.0
# 4      Adelie                39.1               18.7                181.0
# ...       ...                 ...                ...                  ...
# 54291     NaN                 NaN                NaN                  NaN
# 54292     NaN                 NaN                NaN                  NaN
# 54293     NaN                 NaN                NaN                  NaN
# 54294     NaN                 NaN                NaN                  NaN
# 54295     NaN                 NaN                NaN                  NaN
#
#        Body Mass (g)   Sex Sample ID
# 0             3750.0  MALE       A_1
# ...

# %%
#left merge /join:keeps allrecords from the left dataframe 
df=pd.merge(penguins_simple_df,penguins_sex_df,how="left")
df
# Out:
#       Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0      Adelie                39.1               18.7                181.0
# 1      Adelie                39.1               18.7                181.0
# 2      Adelie                39.1               18.7                181.0
# 3      Adelie                39.1               18.7                181.0
# 4      Adelie                39.1               18.7                181.0
# ...       ...                 ...                ...                  ...
# 54280  Gentoo                49.9               16.1                213.0
# 54281  Gentoo                49.9               16.1                213.0
# 54282  Gentoo                49.9               16.1                213.0
# 54283  Gentoo                49.9               16.1                213.0
# 54284  Gentoo                49.9               16.1                213.0
#
#        Body Mass (g)   Sex Sample ID
# 0             3750.0  MALE       A_1
# ...

# %%
#right merge /join:keeps allrecords from the right dataframe 
pd.merge(penguins_simple_df,penguins_sex_df,how="right")
# Out:
#       Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0      Adelie                39.1               18.7                181.0
# 1      Adelie                39.3               20.6                190.0
# 2      Adelie                39.2               19.6                195.0
# 3      Adelie                38.6               21.2                191.0
# 4      Adelie                34.6               21.1                198.0
# ...       ...                 ...                ...                  ...
# 54291  Gentoo                51.5               16.3                230.0
# 54292  Gentoo                55.1               16.0                230.0
# 54293  Gentoo                48.8               16.2                222.0
# 54294  Gentoo                50.4               15.7                222.0
# 54295  Gentoo                49.9               16.1                213.0
#
#        Body Mass (g)   Sex Sample ID
# 0             3750.0  MALE       A_1
# ...

# %% [markdown]
# ### Missing values

# %% [markdown]
# Q:What can we do with missing values?
# Remove_
# A:REmove  the rows with missing data
# A:Remove the full column(if it has a loot of missing data, if it is not too important)
#
#
# Fill:
# A:e.g. mean or median of the column
# A:mean or median of a group
#   mode for categorical
# A:nearest neigbors

# %%
df.isnull().sum()
# Out:
# Species                0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Sex                    0
# Sample ID              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Species                0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Sex                    0
# Sample ID              0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54285 entries, 0 to 54284
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Species              54285 non-null  object
#  1   Culmen Length (mm)   54285 non-null  float64
#  2   Culmen Depth (mm)    54285 non-null  float64
#  3   Flipper Length (mm)  54285 non-null  float64
#  4   Body Mass (g)        54285 non-null  float64
#  5   Sex                  54285 non-null  object
#  6   Sample ID            54285 non-null  object
# dtypes: float64(4), object(3)
# memory usage: 3.3+ MB

# %%
df.drop(["Comments"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-246d04222144> in <module>
# ----> 1 df.drop(["Comments"],axis=1,inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df["Sex"].fillna("FEMALE",inplace=True)

# %%
df.isnull().sum()
# Out:
# Species                0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Sex                    0
# Sample ID              0
# dtype: int64

# %% [markdown]
# ### Strange Values

# %% [markdown]
# **It might be some character like (.,?)**

# %%
df["Sex"].unique()
# Out:
# array(['MALE', 'FEMALE'], dtype=object)

# %%
df["Sex"].replace(".","MALE",inplace=True)

# %% [markdown]
# ### Save as .csv for further use

# %%
df.to_csv("../Day5/penguins_clean.csv")

# %% [markdown]
# *****BONUS****

# %% [markdown]
# **Creating an empty dataframe to append to**

# %%
dfe=pd.DataFrame(columns=adelie_df.columns)
dfe
# Out:
# Empty DataFrame
# Columns: [studyName, Sample Number, Species, Sample ID, Region, Island, Individual ID, Culmen Length (mm), Culmen Depth (mm), Flipper Length (mm), Body Mass (g), Comments]
# Index: []
