# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.dates as mdates

# %%
df=pd.read_csv("flights_train.csv")

# %%
df
# Out:
#            date  passengers
# 0    1949-01-01          64
# 1    1949-02-01          75
# 2    1949-03-01          98
# 3    1949-04-01          93
# 4    1949-05-01          80
# ..          ...         ...
# 127  1959-08-01         430
# 128  1959-09-01         383
# 129  1959-10-01         351
# 130  1959-11-01         323
# 131  1959-12-01         350
#
# [132 rows x 2 columns]

# %%
plt.plot(df["date"],df["passengers"])

# %%
x=df["date"]
x=pd.DatetimeIndex(x).year
x=pd.to_datetime(df["date"])

# %%
plt.plot(x,df["passengers"])
